# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ### Đọc tập dữ liệu

# %%
#Khởi tạo đường dẫn 

books_filename = "BX-Books.csv"

ratings_filename = "BX-Book-Ratings.csv"

users_filename = "BX-Users.csv"

# %%
#Đọc tập dữ liệu, xử lý sang dạng DataFrame

df_books = pd.read_csv(
    books_filename,
    encoding = "ISO-8859-1",
    sep=";",
    header=0,
    names=['isbn', 'title', 'author','year'],
    usecols=['isbn', 'title', 'author','year'],
    dtype=str)

df_ratings = pd.read_csv(
    ratings_filename,
    encoding = "ISO-8859-1",
    sep=";",
    header=0,
    names=['user', 'isbn', 'rating'],
    usecols=['user', 'isbn', 'rating'],
    dtype={'user': 'int32', 'isbn': 'str', 'rating': 'float32'})

# %%
# In tập df_books
print(df_books)
print(df_ratings)
# Out:
#               isbn                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374  0440400988                         There's a Bat in Bunk Five
# 271375  0525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271377  0192126040                        Republic (World's Classics)
# 271378  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# 2               Carlo D'Este  1991
# 3           Gina Bari Kolata  1999
# 4            E. J. W. Barber  1999
# ...                      ...   ...
# 271374        Paula Danziger  1988
# 271375            Teri Sloat  1991
# 271376      Christine Wicker  2004
# 271377                 Plato  1996
# 271378   Christopher  Biffle  2000
#
# [271379 rows x 4 columns]
#            user         isbn  rating
# 0        276725   034545104X     0.0
# 1        276726   0155061224     5.0
# 2        276727   0446520802     0.0
# 3        276729   052165615X     3.0
# 4        276729   0521795028     6.0
# ...         ...          ...     ...
# 1149775  276704   1563526298     9.0
# 1149776  276706   0679447156     0.0
# 1149777  276709   0515107662    10.0
# 1149778  276721   0590442449    10.0
# 1149779  276723  05162443314     8.0
#
# [1149780 rows x 3 columns]

# %% [markdown]
# ### Tiền xử lý dữ liệu

# %%
# Loại bỏ giá trị không hợp lệ trong cột 'year'

invalid_years = df_books[~df_books['year'].str.isnumeric()]

print("Giá trị không hợp lệ trong cột 'year':")

print(invalid_years)
# Out:
# Giá trị không hợp lệ trong cột 'year':
#               isbn                                              title  \
# 6450    0735201994  Peterman Rides Again: Adventures Continue with...
# 43665   0330482750     Three Novels: \A Strange and Sublime Address\"
# 51749   0413326608  Upon my word!: More stories from \My word!\" a...
# 92036   0440500702  Schrodinger's Cat Trilogy : \The Universe Next...
# 104317  0373166982           Please Say \I Do\"  (Three Weddings &amp
# 121766  0894805959  The Best of the Journal of Irreproducible Resu...
# 144056  8423920143  GuÃ­a del lector del \Quijote\": Ensayo psicol...
# 150787  034050823X       The Double Detective: \The Blank Page\" &amp
# 157126  039482492X  C is for Clown: A Circus of \C\" Words, (Brigh...
# 180187  0553570722         \R\" for Revenge: Written by Kate William
# 185736  096401811X  Solid as a rock \I\" stand: Inspirational poet...
# 209386  085409878X                                      \Pie-powder\"
# 209550  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 220624  1874100055                            \The Dead Donkey\" &amp
# 220744  2070426769  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...
# 221691  0789466953  DK Readers: Creating the X-Men, How Comic Book...
# 227931  0006479839  The LaVyrle Spencer Collection:  Three Classic...
# 228955  0807735132              \The Having of Wonderful Ideas\" &amp
# 245931  0394720784  \Your Isadora\": The love story of Isadora Dun...
# 251294  0723245827                    \The World of Peter Rabbit &amp
# 259939  1581801653               Artist\s Photo Reference: Water &amp
# 261527  006263545X  Ludwig van Beethoven: Play by Play/Symphony No...
#
#                                                    author  \
# 6450                                the Catalog Business"
# 43665                                  \"Afternoon Raag\"
# 51749                                       Tony Shryane"
# 92036                             \"The Homing Pigeons\""
# 104317   A Hurricane) (Harlequin American Romance, No ...
# 121766                              Unfounded Findings\""
# 144056                                      14 : Ensayo)"
# 150787                  \"A Fix Like This\" (Crime Club)"
# 157126              early books for beginning beginners)"
# 180187   Created by Francine Pascal (Sweet Valley High...
# 185736                                     short stories"
# 209386                   being dust from the law courts,"
# 209550                                               2000
# 220624                         \"The Guillotined Woman\""
# 220744                                               2003
# 221691                                               2000
# 227931                           \"Forsaking All Others\"
# 228955                      Other Essays on Teaching &amp
# 245931                                      Gordon Craig"
# 251294               Friends\" Complete Story Collection"
# 259939                   Skies (Artists Photo Reference)"
# 261527                           The \"Egmont\" Overture"
#
#                          year
# 6450            John Peterman
# 43665       \"Freedom Song\""
# 51749              Frank Muir
# 92036        ROBERT A. WILSON
# 104317   Karen T. Whittenburg
# 121766       George H. Scherr
# 144056  Salvador de Madariaga
# 150787       K.C. Constantine
# 157126        Stan Berenstain
# 180187        Francine Pascal
# 185736            Luella Hill
# 209386    John Alderson Foote
# 209550      DK Publishing Inc
# 220624            Jules Janin
# 220744              Gallimard
# 221691      DK Publishing Inc
# 227931                   &amp
# 228955              Learning"
# 245931         Isadora Duncan
# 251294         Beatrix Potter
# 259939             Bart Rulon
# 261527              Alan Rich

# %%
df_books['year'] = pd.to_numeric(df_books['year'], errors='coerce')  # Chuyển đổi year từ kiểu str sang numeric, coerce - nếu không chuyển được gán NaN

df_books = df_books.dropna(subset=['year']).astype({'year': 'int32'}) # Loại bỏ giá trị NaN trong year

df_books
print("Số lượng giá trị duy nhất trong cột 'Book-Title':", df_books['title'].nunique())
print("Số lượng giá trị duy nhất trong cột 'Book-Author':", df_books['author'].nunique())
# Out:
# Số lượng giá trị duy nhất trong cột 'Book-Title': 242132
# Số lượng giá trị duy nhất trong cột 'Book-Author': 102020

# %%
df_books
# Out:
#               isbn                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374  0440400988                         There's a Bat in Bunk Five
# 271375  0525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271377  0192126040                        Republic (World's Classics)
# 271378  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# 2               Carlo D'Este  1991
# 3           Gina Bari Kolata  1999
# 4            E. J. W. Barber  1999
# ...                      ...   ...
# 271374        Paula Danziger  1988
# 271375            Teri Sloat  1991
# 271376      Christine Wicker  2004
# 271377                 Plato  1996
# 271378   Christopher  Biffle  2000
#
# [271357 rows x 4 columns]

# %%
# Kiểm tra dữ liệu
chech_nan = df_books.isna().any().any()
if chech_nan == True:
    print("Dữ liệu bị thiếu")
else:
    print("Dữ liệu đầy đủ")
# Out:
# Dữ liệu bị thiếu

# %%
df_books.dropna(inplace=True)
df_books
# Out:
#               isbn                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374  0440400988                         There's a Bat in Bunk Five
# 271375  0525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271377  0192126040                        Republic (World's Classics)
# 271378  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# 2               Carlo D'Este  1991
# 3           Gina Bari Kolata  1999
# 4            E. J. W. Barber  1999
# ...                      ...   ...
# 271374        Paula Danziger  1988
# 271375            Teri Sloat  1991
# 271376      Christine Wicker  2004
# 271377                 Plato  1996
# 271378   Christopher  Biffle  2000
#
# [271355 rows x 4 columns]

# %%
df_ratings
# Out:
#            user         isbn  rating
# 0        276725   034545104X     0.0
# 1        276726   0155061224     5.0
# 2        276727   0446520802     0.0
# 3        276729   052165615X     3.0
# 4        276729   0521795028     6.0
# ...         ...          ...     ...
# 1149775  276704   1563526298     9.0
# 1149776  276706   0679447156     0.0
# 1149777  276709   0515107662    10.0
# 1149778  276721   0590442449    10.0
# 1149779  276723  05162443314     8.0
#
# [1149780 rows x 3 columns]

# %%
df_merge = pd.merge(df_books,df_ratings,on = "isbn",how = "inner")
df_merge
# Out:
#                isbn                                              title  \
# 0        0195153448                                Classical Mythology
# 1        0002005018                                       Clara Callan
# 2        0002005018                                       Clara Callan
# 3        0002005018                                       Clara Callan
# 4        0002005018                                       Clara Callan
# ...             ...                                                ...
# 1031125  0440400988                         There's a Bat in Bunk Five
# 1031126  0525447644                            From One to One Hundred
# 1031127  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1031128  0192126040                        Republic (World's Classics)
# 1031129  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                        author  year    user  rating
# 0          Mark P. O. Morford  2002       2     0.0
# 1        Richard Bruce Wright  2001       8     5.0
# 2        Richard Bruce Wright  2001   11400     0.0
# 3        Richard Bruce Wright  2001   11676     8.0
# 4        Richard Bruce Wright  2001   41385     0.0
# ...                       ...   ...     ...     ...
# 1031125        Paula Danziger  1988  276463     7.0
# 1031126            Teri Sloat  1991  276579     4.0
# 1031127      Christine Wicker  2004  276680     0.0
# 1031128                 Plato  1996  276680     0.0
# 1031129   Christopher  Biffle  2000  276680     0.0
#
# [1031130 rows x 6 columns]

# %%
chech_nan = df_merge.isna().any().any()
if chech_nan == True:
    print("Dữ liệu bị thiếu")
else:
    print("Dữ liệu đầy đủ")
# Out:
# Dữ liệu đầy đủ

# %%
users=df_merge["user"].value_counts()
isbn= df_merge["isbn"].value_counts()

users=users[users>=200].index #Giữ lại các user có số lần xuất hiện từ 200 trở lên.
isbn=isbn[isbn>=100].index #Giữ lại các isbn (mã sách) xuất hiện từ 100 lần trở lên.

df_merge_new=df_merge.loc[(df_merge["user"].isin(users.values))&(df_merge["isbn"].isin(isbn.values))]
df_merge_new
# Out:
#               isbn                                              title  \
# 103     0440234743                                      The Testament
# 105     0440234743                                      The Testament
# 108     0440234743                                      The Testament
# 114     0440234743                                      The Testament
# 117     0440234743                                      The Testament
# ...            ...                                                ...
# 505459  0515135739  Eleventh Hour: An FBI Thriller (FBI Thriller (...
# 505464  0515135739  Eleventh Hour: An FBI Thriller (FBI Thriller (...
# 505465  0515135739  Eleventh Hour: An FBI Thriller (FBI Thriller (...
# 505468  0515135739  Eleventh Hour: An FBI Thriller (FBI Thriller (...
# 505469  0515135739  Eleventh Hour: An FBI Thriller (FBI Thriller (...
#
#                    author  year    user  rating
# 103          John Grisham  1999    2977     0.0
# 105          John Grisham  1999    3363     0.0
# 108          John Grisham  1999    7346     9.0
# 114          John Grisham  1999   11676     9.0
# 117          John Grisham  1999   13552     8.0
# ...                   ...   ...     ...     ...
# 505459  Catherine Coulter  2004  236283     0.0
# 505464  Catherine Coulter  2004  251613     0.0
# 505465  Catherine Coulter  2004  252071     0.0
# 505468  Catherine Coulter  2004  256407     0.0
# 505469  Catherine Coulter  2004  262399     0.0
#
# [48358 rows x 6 columns]

# %%
df_merge_newdrop=df_merge_new.drop_duplicates(['title','user']) # Chỉ giữ lại bản ghi đầu tiên trong các bản ghi trùng lặp.
print("Ma trận merge: ")
print(df_merge_newdrop)

print("Danh sách title: ")
listcl = pd.unique(df_merge_newdrop['title'].values.tolist()) # Tạo danh sách các tiêu đề sách duy nhất
for i in range(len(listcl)):
    print("Sách {}:{}".format(i,listcl[i]))
# Out:
# Ma trận merge:
#               isbn                                              title  \
# 103     0440234743                                      The Testament
# 105     0440234743                                      The Testament
# 108     0440234743                                      The Testament
# 114     0440234743                                      The Testament
# 117     0440234743                                      The Testament
# ...            ...                                                ...
# 505459  0515135739  Eleventh Hour: An FBI Thriller (FBI Thriller (...
# 505464  0515135739  Eleventh Hour: An FBI Thriller (FBI Thriller (...
# 505465  0515135739  Eleventh Hour: An FBI Thriller (FBI Thriller (...
# 505468  0515135739  Eleventh Hour: An FBI Thriller (FBI Thriller (...
# 505469  0515135739  Eleventh Hour: An FBI Thriller (FBI Thriller (...
#
#                    author  year    user  rating
# 103          John Grisham  1999    2977     0.0
# 105          John Grisham  1999    3363     0.0
# 108          John Grisham  1999    7346     9.0
# 114          John Grisham  1999   11676     9.0
# 117          John Grisham  1999   13552     8.0
# ...                   ...   ...     ...     ...
# 505459  Catherine Coulter  2004  236283     0.0
# 505464  Catherine Coulter  2004  251613     0.0
# 505465  Catherine Coulter  2004  252071     0.0
# 505468  Catherine Coulter  2004  256407     0.0
# 505469  Catherine Coulter  2004  262399     0.0
#
# [47978 rows x 6 columns]
# Danh sách title:
# Sách 0:The Testament
# Sách 1:Beloved (Plume Contemporary Fiction)
# Sách 2:Wild Animus
# Sách 3:Airframe
# Sách 4:Timeline
# Sách 5:To Kill a Mockingbird
# Sách 6:Seabiscuit: An American Legend
# Sách 7:I'll Be Seeing You
# Sách 8:From the Corner of His Eye
# Sách 9:Isle of Dogs
# Sách 10:Purity in Death
# Sách 11:Left Behind: A Novel of the Earth's Last Days (Left Behind #1)
# Sách 12:The Street Lawyer
# Sách 13:Breathing Lessons
# Sách 14:The Joy Luck Club
# Sách 15:The Tao of Pooh
# Sách 16:Seabiscuit
# Sách 17:The Catcher in the Rye
# Sách 18:Midnight in the Garden of Good and Evil: A Savannah Story
# Sách 19:Pretend You Don't See Her
# Sách 20:The Pillars of the Earth
# Sách 21:Corelli's Mandolin : A Novel
# Sách 22:The Five People You Meet in Heaven
# Sách 23:The Beach House
# Sách 24:Angels &amp; Demons
# Sách 25:The Girl Who Loved Tom Gordon
# Sách 26:The Sum of All Fears
# Sách 27:Little Altars Everywhere: A Novel
# Sách 28:Before I Say Good-Bye
# Sách 29:Atonement : A Novel
# Sách 30:Bridget Jones's Diary
# Sách 31:The God of Small Things
# Sách 32:The Big Bad Wolf: A Novel
# Sách 33:Four Blind Mice
# Sách 34:Congo
# Sách 35:Plainsong (Vintage Contemporaries)
# Sách 36:Body of Evidence (Kay Scarpetta Mysteries (Paperback))
# Sách 37:All That Remains (Kay Scarpetta Mysteries (Paperback))
# Sách 38:The Brethren
# Sách 39:The King of Torts
# Sách 40:Bleachers
# Sách 41:Sisterhood of the Traveling Pants
# Sách 42:Roses Are Red (Alex Cross Novels)
# Sách 43:The Rescue
# Sách 44:Manhattan Hunt Club
# Sách 45:Girl with a Pearl Earring
# Sách 46:Deception Point
# Sách 47:Tis : A Memoir
# Sách 48:Chicken Soup for the Soul (Chicken Soup for the Soul)
# Sách 49:Wicked: The Life and Times of the Wicked Witch of the West
# Sách 50:Life of Pi
# Sách 51:Lies and the Lying Liars Who Tell Them: A Fair and Balanced Look at the Right
# Sách 52:Secret History
# Sách 53:Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series (Paper))
# Sách 54:The Weight of Water
# Sách 55:Animal Farm
# Sách 56:Catch 22
# Sách 57:A Painted House
# Sách 58:Vinegar Hill (Oprah's Book Club (Paperback))
# Sách 59:The Secret Life of Bees
# Sách 60:Digital Fortress : A Thriller
# Sách 61:The Client
# Sách 62:Heart of the Sea (Irish Trilogy)
# Sách 63:Jonathan Livingston Seagull
# Sách 64:Moonlight Becomes You
# Sách 65:Divine Secrets of the Ya-Ya Sisterhood : A Novel
# Sách 66:The Perfect Storm : A True Story of Men Against the Sea
# Sách 67:The Lovely Bones: A Novel
# Sách 68:Hannibal
# Sách 69:The Four Agreements: A Practical Guide to Personal Freedom
# Sách 70:The Firm
# Sách 71:A Widow for One Year
# Sách 72:Empire Falls
# Sách 73:Black and Blue
# Sách 74:She's Come Undone (Oprah's Book Club)
# Sách 75:Nickel and Dimed: On (Not) Getting By in America
# Sách 76:Left Behind: A Novel of the Earth's Last Days (Left Behind No. 1)
# Sách 77:The Bean Trees
# Sách 78:Daughter of Fortune
# Sách 79:The Red Tent (Bestselling Backlist)
# Sách 80:The Nanny Diaries: A Novel
# Sách 81:Postmortem
# Sách 82:While My Pretty One Sleeps
# Sách 83:Three Junes
# Sách 84:Back Roads
# Sách 85:A Thousand Acres (Ballantine Reader's Circle)
# Sách 86:Four Blondes
# Sách 87:River's End
# Sách 88:The Chamber
# Sách 89:The Partner
# Sách 90:Chosen Prey
# Sách 91:Guilty as Sin
# Sách 92:Night Sins
# Sách 93:The Vampire Lestat (Vampire Chronicles, Book II)
# Sách 94:The Mummy or Ramses the Damned
# Sách 95:Daisy Fay and the Miracle Man
# Sách 96:Angela's Ashes: A Memoir
# Sách 97:The Next Accident
# Sách 98:Fast Food Nation: The Dark Side of the All-American Meal
# Sách 99:Echoes
# Sách 100:One for the Money (Stephanie Plum Novels (Paperback))
# Sách 101:Along Came a Spider (Alex Cross Novels)
# Sách 102:Simple Abundance:  A Daybook of Comfort and Joy
# Sách 103:Who Moved My Cheese? An Amazing Way to Deal with Change in Your Work and in Your Life
# Sách 104:Where the Heart Is (Oprah's Book Club (Paperback))
# Sách 105:The Girls' Guide to Hunting and Fishing
# Sách 106:Icy Sparks
# Sách 107:The Da Vinci Code
# Sách 108:Bridget Jones : The Edge of Reason
# Sách 109:The Pilot's Wife : A Novel Tag: Author of the Weight of Water (Oprah's Book Club (Hardcover))
# Sách 110:Skipping Christmas
# Sách 111:Daddy's Little Girl
# Sách 112:Nights in Rodanthe
# Sách 113:Like Water for Chocolate: A Novel in Monthly Installments, With Recipes, Romances, and Home Remedies
# Sách 114:The Two Towers (The Lord of the Rings, Part 2)
# Sách 115:Suzanne's Diary for Nicholas
# Sách 116:2nd Chance
# Sách 117:The Bad Beginning (A Series of Unfortunate Events, Book 1)
# Sách 118:Me Talk Pretty One Day
# Sách 119:The Door to December
# Sách 120:About a Boy (Movie Tie-In)
# Sách 121:Dreamcatcher
# Sách 122:Smilla's Sense of Snow
# Sách 123:The Hitchhiker's Guide to the Galaxy
# Sách 124:The Giver (21st Century Reference)
# Sách 125:A Time to Kill
# Sách 126:Charming Billy
# Sách 127:Dark Paradise
# Sách 128:Middlesex: A Novel
# Sách 129:The Rainmaker
# Sách 130:The Bad Place
# Sách 131:The Amazing Adventures of Kavalier &amp; Clay
# Sách 132:The Phantom Tollbooth
# Sách 133:Dances With Wolves
# Sách 134:The Princess Bride: S Morgenstern's Classic Tale of True Love and High Adventure
# Sách 135:Degree of Guilt
# Sách 136:SHIPPING NEWS
# Sách 137:Anne of Green Gables (Anne of Green Gables Novels (Paperback))
# Sách 138:Fall On Your Knees (Oprah #45)
# Sách 139:While I Was Gone
# Sách 140:The House of the Spirits
# Sách 141:Interpreter of Maladies
# Sách 142:Divine Secrets of the Ya-Ya Sisterhood: A Novel
# Sách 143:She's Come Undone (Oprah's Book Club (Paperback))
# Sách 144:Dragonfly in Amber
# Sách 145:Naked
# Sách 146:Kiss the Girls
# Sách 147:The Witching Hour (Lives of the Mayfair Witches)
# Sách 148:Jack &amp; Jill (Alex Cross Novels)
# Sách 149:The House on Mango Street (Vintage Contemporaries)
# Sách 150:The Perks of Being a Wallflower
# Sách 151:Daughter of Fortune : A Novel (Oprah's Book Club (Hardcover))
# Sách 152:American Gods
# Sách 153:Red Dragon
# Sách 154:Jurassic Park
# Sách 155:Neverwhere
# Sách 156:The Thorn Birds
# Sách 157:Forever... : A Novel of Good and Evil, Love and Hope
# Sách 158:Memoirs of a Geisha Uk
# Sách 159:Lamb : The Gospel According to Biff, Christ's Childhood Pal
# Sách 160:The Color of Water: A Black Man's Tribute to His White Mother
# Sách 161:Anne Frank: The Diary of a Young Girl
# Sách 162:The Stand: Complete and Uncut
# Sách 163:Shopaholic Takes Manhattan (Summer Display Opportunity)
# Sách 164:Confessions of a Shopaholic (Summer Display Opportunity)
# Sách 165:Table For Two
# Sách 166:Good Omens
# Sách 167:Message in a Bottle
# Sách 168:Fatal Voyage
# Sách 169:The Poisonwood Bible: A Novel
# Sách 170:A Lesson Before Dying (Vintage Contemporaries (Paperback))
# Sách 171:Jewel
# Sách 172:Their Eyes Were Watching God: A Novel
# Sách 173:A Prayer for Owen Meany
# Sách 174:The Shipping News : A Novel
# Sách 175:The No. 1 Ladies' Detective Agency (Today Show Book Club #8)
# Sách 176:Shopgirl
# Sách 177:Breath, Eyes, Memory
# Sách 178:A Walk in the Woods: Rediscovering America on the Appalachian Trail (Official Guides to the Appalachian Trail)
# Sách 179:The Kitchen God's Wife
# Sách 180:Songs in Ordinary Time (Oprah's Book Club (Paperback))
# Sách 181:The Last Juror
# Sách 182:Valhalla Rising (Dirk Pitt Adventures (Paperback))
# Sách 183:At Home in Mitford (The Mitford Years)
# Sách 184:Bel Canto: A Novel
# Sách 185:All Around the Town
# Sách 186:A Civil Action
# Sách 187:Faking It
# Sách 188:The Loop
# Sách 189:Good in Bed
# Sách 190:We'll Meet Again
# Sách 191:How to Make an American Quilt
# Sách 192:Ellen Foster
# Sách 193:The Hours : A Novel
# Sách 194:Cold Mountain : A Novel
# Sách 195:Fried Green Tomatoes at the Whistle Stop Cafe
# Sách 196:The Last Time They Met : A Novel
# Sách 197:The Princess Diaries
# Sách 198:A Heartbreaking Work of Staggering Genius
# Sách 199:The Dress Lodger (Ballantine Reader's Circle)
# Sách 200:The Fellowship of the Ring (The Lord of the Rings, Part 1)
# Sách 201:The Blue Nowhere : A Novel
# Sách 202:A Year in Provence
# Sách 203:The Sparrow
# Sách 204:Summer Sisters
# Sách 205:What to Expect When You're Expecting (Revised Edition)
# Sách 206:Miss Julia Speaks Her Mind : A Novel
# Sách 207:Big Stone Gap: A Novel (Ballantine Reader's Circle)
# Sách 208:The Reader
# Sách 209:Back When We Were Grownups : A Novel (Ballantine Reader's Circle)
# Sách 210:Black Notice
# Sách 211:One for the Money (A Stephanie Plum Novel)
# Sách 212:Lord of the Flies
# Sách 213:Atlantis Found
# Sách 214:The Alienist
# Sách 215:Notes from a Small Island
# Sách 216:Engaging The Enemy
# Sách 217:Into the Wild
# Sách 218:The Curious Incident of the Dog in the Night-Time (Today Show Book Club #13)
# Sách 219:The Smoke Jumper
# Sách 220:Cause of Death
# Sách 221:The Alchemist: A Fable About Following Your Dream
# Sách 222:The Poisonwood Bible
# Sách 223:Point of Origin
# Sách 224:Rising Sun
# Sách 225:Black Friday
# Sách 226:1st to Die: A Novel
# Sách 227:Into Thin Air : A Personal Account of the Mt. Everest Disaster
# Sách 228:Snow Falling on Cedars
# Sách 229:Everything's Eventual : 14 Dark Tales
# Sách 230:Here on Earth
# Sách 231:The Lost World
# Sách 232:The Shelters of Stone (Earth's Children Series, No 5)
# Sách 233:White Oleander : A Novel
# Sách 234:CAT'S EYE
# Sách 235:The Handmaid's Tale
# Sách 236:The Girl Who Loved Tom Gordon : A Novel
# Sách 237:The Murder Book
# Sách 238:Body of Lies
# Sách 239:Ishmael: An Adventure of the Mind and Spirit
# Sách 240:Lightning
# Sách 241:Hearts In Atlantis
# Sách 242:Eyes of the Dragon
# Sách 243:The Dive From Clausen's Pier : A Novel (Vintage Contemporaries (Paperback))
# Sách 244:The Simple Truth
# Sách 245:A Light in the Window (The Mitford Years)
# Sách 246:1984
# Sách 247:The Mists of Avalon
# Sách 248:Hot Six : A Stephanie Plum Novel (A Stephanie Plum Novel)
# Sách 249:Jemima J: A Novel About Ugly Ducklings and Swans
# Sách 250:Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# Sách 251:Sea Glass: A Novel
# Sách 252:Daughter of Fortune: A Novel
# Sách 253:Seven Habits Of Highly Effective People
# Sách 254:Fahrenheit 451
# Sách 255:Ender's Game (Ender Wiggins Saga (Paperback))
# Sách 256:The Andromeda Strain
# Sách 257:Loves Music, Loves to Dance
# Sách 258:The Killer Angels
# Sách 259:Dolores Claiborne
# Sách 260:The Eye of the World (The Wheel of Time, Book 1)
# Sách 261:Clear and Present Danger (Jack Ryan Novels)
# Sách 262:Tuesdays with Morrie: An Old Man, a Young Man, and Life's Greatest Lesson
# Sách 263:Pigs in Heaven
# Sách 264:Tell No One
# Sách 265:Eats, Shoots &amp; Leaves: The Zero Tolerance Approach to Punctuation
# Sách 266:Waiting (Vintage International)
# Sách 267:The Sum of All Fears (Jack Ryan Novels)
# Sách 268:Icebound
# Sách 269:Mystic River
# Sách 270:The Jester
# Sách 271:Sick Puppy
# Sách 272:Prey
# Sách 273:Fear Nothing
# Sách 274:J Is for Judgment
# Sách 275:A Is for Alibi (Kinsey Millhone Mysteries (Paperback))
# Sách 276:Sphere
# Sách 277:Slow Waltz in Cedar Bend
# Sách 278:The Pelican Brief
# Sách 279:Bridget Jones: The Edge of Reason
# Sách 280:Don't Stand Too Close to a Naked Man
# Sách 281:Interview with the Vampire
# Sách 282:The Queen of the Damned (Vampire Chronicles (Paperback))
# Sách 283:\O\" Is for Outlaw"
# Sách 284:The Book of Ruth (Oprah's Book Club (Paperback))
# Sách 285:How to Be Good
# Sách 286:The Color Purple
# Sách 287:The Notebook
# Sách 288:A Beautiful Mind: The Life of Mathematical Genius and Nobel Laureate John Nash
# Sách 289:You Belong To Me
# Sách 290:Peace Like a River
# Sách 291:Cry Wolf
# Sách 292:Montana Sky
# Sách 293:Diary of a Mad Bride (Summer Display Opportunity)
# Sách 294:Carolina Moon
# Sách 295:Standing in the Rainbow
# Sách 296:East of Eden (Oprah's Book Club)
# Sách 297:Three Fates
# Sách 298:Pay It Forward
# Sách 299:Bastard Out of Carolina
# Sách 300:Face the Fire (Three Sisters Island Trilogy)
# Sách 301:Stupid White Men ...and Other Sorry Excuses for the State of the Nation!
# Sách 302:Harry Potter and the Sorcerer's Stone (Book 1)
# Sách 303:Dude, Where's My Country?
# Sách 304:Bee Season: A Novel
# Sách 305:ANGELA'S ASHES
# Sách 306:Violets Are Blue
# Sách 307:The Dogs of Babel (Today Show Book Club #12)
# Sách 308:The Tale of the Body Thief (Vampire Chronicles (Paperback))
# Sách 309:Cruel &amp; Unusual (Kay Scarpetta Mysteries (Paperback))
# Sách 310:Misery
# Sách 311:The Eyre Affair: A Novel
# Sách 312:The Body Farm
# Sách 313:Intensity
# Sách 314:Dark Rivers of the Heart
# Sách 315:Mr. Murder
# Sách 316:The Hours: A Novel
# Sách 317:The Bonesetter's Daughter
# Sách 318:Midwives: A Novel
# Sách 319:Song of Solomon (Oprah's Book Club (Paperback))
# Sách 320:Atlas Shrugged
# Sách 321:I Know This Much Is True
# Sách 322:To the Nines: A Stephanie Plum Novel
# Sách 323:Don't Sweat the Small Stuff and It's All Small Stuff : Simple Ways to Keep the Little Things from Taking Over Your Life (Don't Sweat the Small Stuff Series)
# Sách 324:Monster : A Novel (Alex Delaware Novels (Paperback))
# Sách 325:Call of the Wild
# Sách 326:Girl, Interrupted
# Sách 327:Wish You Well
# Sách 328:Four To Score (A Stephanie Plum Novel)
# Sách 329:Rising Tides
# Sách 330:Watership Down
# Sách 331:High Five (A Stephanie Plum Novel)
# Sách 332:Five Quarters of the Orange
# Sách 333:Like Water for Chocolate: A Novel in Monthly Installments With Recipes, Romances and Home Remedies
# Sách 334:The Dive From Clausen's Pier (Alex Awards)
# Sách 335:A Child Called \It\": One Child's Courage to Survive"
# Sách 336:Final Target
# Sách 337:A Map of the World
# Sách 338:Siddhartha
# Sách 339:Tribulation Force: The Continuing Drama of Those Left Behind (Left Behind No. 2)
# Sách 340:The Runaway Jury
# Sách 341:Without Remorse
# Sách 342:The Bear and the Dragon (Jack Ryan Novels)
# Sách 343:The Woman Next Door
# Sách 344:The Divine Secrets of the Ya-Ya Sisterhood: A Novel
# Sách 345:The Color of Magic
# Sách 346:The Hobbit : The Enchanting Prelude to The Lord of the Rings
# Sách 347:Chicken Soup for the Teenage Soul (Chicken Soup for the Soul)
# Sách 348:Contact
# Sách 349:The Temple of My Familiar
# Sách 350:Harry Potter and the Chamber of Secrets (Book 2)
# Sách 351:Love in the Time of Cholera (Penguin Great Books of the 20th Century)
# Sách 352:Ashes to Ashes
# Sách 353:The Professor and the Madman: A Tale of Murder, Insanity, and the Making of The Oxford English Dictionary
# Sách 354:The Plains of Passage (Earth's Children (Paperback))
# Sách 355:Cane River
# Sách 356:The Surgeon
# Sách 357:Presumed Innocent
# Sách 358:Anne of Avonlea (Anne of Green Gables Novels (Paperback))
# Sách 359:Pleading Guilty
# Sách 360:Politically Correct Bedtime Stories: Modern Tales for Our Life and Times
# Sách 361:4 Blondes
# Sách 362:Night
# Sách 363:STONES FROM THE RIVER
# Sách 364:Falling Angels
# Sách 365:The Valley of Horses
# Sách 366:Desperation
# Sách 367:Harry Potter and the Prisoner of Azkaban (Book 3)
# Sách 368:Charlotte's Web (Trophy Newbery)
# Sách 369:The Lottery Winner : Alvirah And Willy Stories
# Sách 370:Lucky : A Memoir
# Sách 371:Let Me Call You Sweetheart
# Sách 372:K Is for Killer (Kinsey Millhone Mysteries (Paperback))
# Sách 373:Unspeakable
# Sách 374:Irish Hearts
# Sách 375:Catch Me If You Can: The True Story of a Real Fake
# Sách 376:Circle of Friends
# Sách 377:The Bourne Identity
# Sách 378:Under the Tuscan Sun
# Sách 379:Tis: A Memoir
# Sách 380:The Cardinal of the Kremlin (Jack Ryan Novels)
# Sách 381:Bag of Bones
# Sách 382:The Prince of Tides
# Sách 383:A Bend in the Road
# Sách 384:Shopaholic Ties the Knot
# Sách 385:One Door Away from Heaven
# Sách 386:How the Garcia Girls Lost Their Accents (Plume Contemporary Fiction)
# Sách 387:The Bridges of Madison County
# Sách 388:The Return of the King (The Lord of the Rings, Part 3)
# Sách 389:High Fidelity
# Sách 390:A Confederacy of Dunces (Evergreen Book)
# Sách 391:Mrs Dalloway
# Sách 392:Prodigal Summer
# Sách 393:Flesh and Blood
# Sách 394:White Oleander : A Novel (Oprah's Book Club)
# Sách 395:Confessions of an Ugly Stepsister : A Novel
# Sách 396:Zen and the Art of Motorcycle Maintenance: An Inquiry into Values
# Sách 397:Dying for Chocolate (Culinary Mysteries (Paperback))
# Sách 398:The Reef
# Sách 399:House of Sand and Fog
# Sách 400:Saving Faith
# Sách 401:The Mulberry Tree
# Sách 402:White Teeth: A Novel
# Sách 403:Sophie's World: A Novel About the History of Philosophy
# Sách 404:Silence of the Lambs
# Sách 405:The Hot Zone
# Sách 406:The Rapture of Canaan
# Sách 407:Heaven and Earth (Three Sisters Island Trilogy)
# Sách 408:Dance upon the Air (Three Sisters Island Trilogy)
# Sách 409:What Looks Like Crazy On An Ordinary Day
# Sách 410:Angela's Ashes (MMP) : A Memoir
# Sách 411:The Corrections: A Novel
# Sách 412:Shopgirl : A Novella
# Sách 413:The Reptile Room (A Series of Unfortunate Events, Book 2)
# Sách 414:Coraline
# Sách 415:Long After Midnight
# Sách 416:Stranger in a Strange Land (Remembering Tomorrow)
# Sách 417:Disclosure
# Sách 418:The Idiot Girls' Action Adventure Club
# Sách 419:The Corrections
# Sách 420:The Golden Compass (His Dark Materials, Book 1)
# Sách 421:The Pilot's Wife : A Novel
# Sách 422:About a Boy
# Sách 423:A Patchwork Planet
# Sách 424:Prey: A Novel
# Sách 425:Blessings
# Sách 426:Shell Seekers
# Sách 427:A Case of Need
# Sách 428:Blow Fly: A Scarpetta Novel
# Sách 429:The Devil Wears Prada : A Novel
# Sách 430:On the Street Where You Live
# Sách 431:Prodigal Summer: A Novel
# Sách 432:We Were the Mulvaneys
# Sách 433:Brave New World
# Sách 434:Balzac and the Little Chinese Seamstress : A Novel
# Sách 435:Year of Wonders
# Sách 436:All I Really Need to Know
# Sách 437:Running with Scissors: A Memoir
# Sách 438:Tara Road
# Sách 439:Hornet's Nest
# Sách 440:The Handmaid's Tale : A Novel
# Sách 441:Chocolat
# Sách 442:The Green Mile
# Sách 443:Harry Potter and the Goblet of Fire (Book 4)
# Sách 444:Slaughterhouse Five or the Children's Crusade: A Duty Dance With Death
# Sách 445:P Is for Peril
# Sách 446:Beach House
# Sách 447:The Celestine Prophecy (Celestine Prophecy)
# Sách 448:Harry Potter and the Order of the Phoenix (Book 5)
# Sách 449:Insomnia
# Sách 450:Hideaway
# Sách 451:The Tommyknockers
# Sách 452:Tears of the Giraffe (No.1 Ladies Detective Agency)
# Sách 453:Rainbow Six
# Sách 454:A Walk to Remember
# Sách 455:Holes (Yearling Newbery)
# Sách 456:The Summons
# Sách 457:The Third Twin
# Sách 458:The Winner
# Sách 459:The Villa
# Sách 460:The Virgin Suicides
# Sách 461:From Potter's Field
# Sách 462:The Summerhouse
# Sách 463:Cold Mountain
# Sách 464:The Blind Assassin
# Sách 465:D Is for Deadbeat (Kinsey Millhone Mysteries (Paperback))
# Sách 466:Midnight in the Garden of Good and Evil
# Sách 467:Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel)
# Sách 468:Two for the Dough
# Sách 469:Where the Red Fern Grows
# Sách 470:The Eyes of Darkness
# Sách 471:Portrait of a Killer: Jack the Ripper -- Case Closed
# Sách 472:Envy
# Sách 473:Big Trouble
# Sách 474:The Samurai's Garden : A Novel
# Sách 475:Dead Sleep
# Sách 476:The Dark Half
# Sách 477:Fast Women
# Sách 478:Full House (Janet Evanovich's Full Series)
# Sách 479:F Is for Fugitive (Kinsey Millhone Mysteries (Paperback))
# Sách 480:E Is for Evidence: A Kinsey Millhone Mystery (Kinsey Millhone Mysteries (Paperback))
# Sách 481:Plum Island
# Sách 482:Beloved
# Sách 483:The Sweet Potato Queens' Book of Love
# Sách 484:Drowning Ruth (Oprah's Book Club)
# Sách 485:The Last Precinct
# Sách 486:September
# Sách 487:Possession : A Romance
# Sách 488:L Is for Lawless
# Sách 489:Turtle Moon
# Sách 490:The Cider House Rules
# Sách 491:Animal Dreams
# Sách 492:Sleepers
# Sách 493:Coast Road: A Novel
# Sách 494:The Angel of Darkness
# Sách 495:Jewel (Oprah's Book Club)
# Sách 496:I Is for Innocent
# Sách 497:Morality for Beautiful Girls (No.1 Ladies Detective Agency)
# Sách 498:N Is for Noose
# Sách 499:A Wrinkle in Time
# Sách 500:The English Patient
# Sách 501:I Know Why the Caged Bird Sings
# Sách 502:The Hunt for Red October
# Sách 503:Still Waters
# Sách 504:Hard Eight : A Stephanie Plum Novel (A Stephanie Plum Novel)
# Sách 505:The No. 1 Ladies' Detective Agency
# Sách 506:Debt of Honor (Jack Ryan Novels)
# Sách 507:The Deep End of the Ocean (Oprah's Book Club (Hardcover))
# Sách 508:Q Is for Quarry
# Sách 509:Full Tilt (Janet Evanovich's Full Series)
# Sách 510:Open House (Oprah's Book Club (Paperback))
# Sách 511:The Forgotten (Peter Decker &amp; Rina Lazarus Novels (Paperback))
# Sách 512:The Glass Lake
# Sách 513:The Horse Whisperer
# Sách 514:River, Cross My Heart
# Sách 515:Girl in Hyacinth Blue
# Sách 516:Angus, Thongs and Full-Frontal Snogging: Confessions of Georgia Nicolson
# Sách 517:Sea Swept (Quinn Brothers (Paperback))
# Sách 518:P Is for Peril (Kinsey Millhone Mysteries (Hardcover))
# Sách 519:The Weight of Water : A Novel Tag: Author of Resistance and Strange Fits of Passion
# Sách 520:Hearts in Atlantis
# Sách 521:It Was on Fire When I Lay Down on It
# Sách 522:Total Control
# Sách 523:Dust to Dust
# Sách 524:Truly, Madly Manhattan
# Sách 525:Survival of the Fittest: An Alex Delaware Novel
# Sách 526:Southern Cross
# Sách 527:Of Mice and Men (Penguin Great Books of the 20th Century)
# Sách 528:B Is for Burglar (Kinsey Millhone Mysteries (Paperback))
# Sách 529:C Is for Corpse (Kinsey Millhone Mysteries (Paperback))
# Sách 530:Gerald's Game
# Sách 531:FORREST GUMP (Movie Tie in)
# Sách 532:Rose Madder
# Sách 533:When the Wind Blows
# Sách 534:Eaters of the Dead
# Sách 535:Neuromancer (Remembering Tomorrow)
# Sách 536:Tom Clancy's Op-Center (Tom Clancy's Op Center (Paperback))
# Sách 537:Last Chance Saloon
# Sách 538:A Man in Full
# Sách 539:Seven Up (A Stephanie Plum Novel)
# Sách 540:Last Man Standing
# Sách 541:The Stone Diaries
# Sách 542:Open House
# Sách 543:The Pilot's Wife
# Sách 544:Dune (Remembering Tomorrow)
# Sách 545:Black House
# Sách 546:A Thin Dark Line (Mysteries &amp; Horror)
# Sách 547:The Perfect Husband
# Sách 548:The Face of Deception
# Sách 549:G Is for Gumshoe (Kinsey Millhone Mysteries (Paperback))
# Sách 550:The Other Boleyn Girl
# Sách 551:The Bonfire of the Vanities
# Sách 552:Lake Wobegon days
# Sách 553:The Search
# Sách 554:Portrait of a Killer: Jack the Ripper-- Case Closed (Berkley True Crime)
# Sách 555:A Girl Named Zippy: Growing Up Small in Mooreland Indiana (Today Show Book Club #3)
# Sách 556:The Virgin Blue
# Sách 557:The Bachelor (Warner Books Contemporary Romance)
# Sách 558:The House of Thunder
# Sách 559:The Bone Collector (Lincoln Rhyme Novels (Paperback))
# Sách 560:Dr. Death (Alex Delaware Novels (Paperback))
# Sách 561:One Flew Over the Cuckoo's Nest
# Sách 562:Four Past Midnight
# Sách 563:Men Are from Mars, Women Are from Venus: A Practical Guide for Improving Communication and Getting What You Want in Your Relationships
# Sách 564:Outlander
# Sách 565:Hemlock Bay
# Sách 566:The Great Gatsby
# Sách 567:Red Storm Rising
# Sách 568:Tell Me Lies (Tell Me Lies)
# Sách 569:Ahab's Wife: Or, The Star-Gazer: A Novel
# Sách 570:Couplehood
# Sách 571:Code to Zero
# Sách 572:Hide &amp; Seek
# Sách 573:Whirlwind (Tyler, Book 1)
# Sách 574:Schindler's List
# Sách 575:Drowning Ruth
# Sách 576:Summer Pleasures
# Sách 577:A Virtuous Woman (Oprah's Book Club (Paperback))
# Sách 578:The Burden of Proof
# Sách 579:False Memory
# Sách 580:Foucault's Pendulum
# Sách 581:See How They Run
# Sách 582:The Liar's Club: A Memoir
# Sách 583:One True Thing
# Sách 584:The Killing Game: Only One Can Win...and the Loser Dies
# Sách 585:Nightmares &amp; Dreamscapes
# Sách 586:Watchers
# Sách 587:Seize the Night
# Sách 588:Needful Things
# Sách 589:From a Buick 8 : A Novel
# Sách 590:Welcome to the World, Baby Girl!
# Sách 591:A Fine Balance
# Sách 592:Deja Dead
# Sách 593:The Ugly Duckling
# Sách 594:In Her Shoes : A Novel
# Sách 595:I Know This Much Is True (Oprah's Book Club)
# Sách 596:Gap Creek: The Story Of A Marriage
# Sách 597:The Hundred Secret Senses
# Sách 598:Welcome to Temptation
# Sách 599:Pop Goes the Weasel
# Sách 600:Tears of the Moon (Irish Trilogy)
# Sách 601:The Genesis Code
# Sách 602:Riptide
# Sách 603:The Accidental Tourist
# Sách 604:The Gunslinger (The Dark Tower, Book 1)
# Sách 605:The Lost Boy: A Foster Child's Search for the Love of a Family
# Sách 606:The Honk and Holler Opening Soon
# Sách 607:Fortune's Rocks: A Novel
# Sách 608:Unnatural Exposure
# Sách 609:Shadowfires
# Sách 610:Thousand Acres
# Sách 611:Remember Me
# Sách 612:The Key to Midnight
# Sách 613:Winter Moon
# Sách 614:Scarlet Feather
# Sách 615:Lucky Man: A Memoir
# Sách 616:Midnight Bayou
# Sách 617:Big Cherry Holler: A Big Stone Gap Novel (Ballantine Reader's Circle)
# Sách 618:Like Water for Chocolate : A Novel in Monthly Installments with Recipes, Romances, and Home Remedies
# Sách 619:Beach Music
# Sách 620:The Saving Graces: A Novel
# Sách 621:Invasion
# Sách 622:Moo
# Sách 623:Tom Clancy's Op-Center: Mirror Image (Tom Clancy's Op Center (Paperback))
# Sách 624:Cradle and All
# Sách 625:Space
# Sách 626:Atonement: A Novel
# Sách 627:Nicolae: The Rise of Antichrist (Left Behind No. 3)
# Sách 628:The Remains of the Day (Vintage International)
# Sách 629:Acceptable Risk
# Sách 630:The Sigma Protocol
# Sách 631:The Clan of the Cave Bear (Earth's Children (Paperback))
# Sách 632:Scarlett : The Sequel to Margaret Mitchell's \Gone With the Wind\""
# Sách 633:Evening Class
# Sách 634:On the Road
# Sách 635:The General's Daughter
# Sách 636:Artemis Fowl (Artemis Fowl, Book 1)
# Sách 637:The Copper Beech
# Sách 638:Key of Knowledge (Key Trilogy (Paperback))
# Sách 639:Key of Valor (Roberts, Nora. Key Trilogy, 3.)
# Sách 640:Key of Light (Key Trilogy (Paperback))
# Sách 641:Wifey
# Sách 642:A Wrinkle In Time
# Sách 643:The Bluest Eye
# Sách 644:The Boy Next Door
# Sách 645:Sanctuary
# Sách 646:Soul Harvest: The World Takes Sides (Left Behind No. 4)
# Sách 647:All the Pretty Horses (The Border Trilogy, Vol 1)
# Sách 648:The Return Journey
# Sách 649:Seinlanguage
# Sách 650:The World According to Garp
# Sách 651:The Stone Monkey (Lincoln Rhyme Novels (Paperback))
# Sách 652:Jewels of the Sun (Irish Trilogy)
# Sách 653:American Psycho (Vintage Contemporaries)
# Sách 654:Silent Night : A Christmas Suspense Story
# Sách 655:H Is for Homicide (Kinsey Millhone Mysteries (Paperback))
# Sách 656:Executive Orders (Jack Ryan Novels)
# Sách 657:Cat &amp; Mouse (Alex Cross Novels)
# Sách 658:Blood Work
# Sách 659:Mortal Prey
# Sách 660:Patriot Games (Jack Ryan Novels)
# Sách 661:Inner Harbor (Quinn Brothers (Paperback))
# Sách 662:Lasher: Lives of the Mayfair Witches (Lives of the Mayfair Witches)
# Sách 663:Crazy for You
# Sách 664:That Camden Summer
# Sách 665:Absolute Power
# Sách 666:The Deep End of the Ocean
# Sách 667:Jackdaws
# Sách 668:Easy Prey
# Sách 669:M Is for Malice
# Sách 670:The Talisman
# Sách 671:Angels
# Sách 672:Eleventh Hour: An FBI Thriller (FBI Thriller (Jove Paperback))
# C:\Users\NC\AppData\Local\Temp\ipykernel_21548\3854661609.py:6: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   listcl = pd.unique(df_merge_newdrop['title'].values.tolist()) # Tạo danh sách các tiêu đề sách duy nhất

# %%
df_pivot = df_merge_newdrop.pivot_table(index='title',columns='user',values='rating',fill_value=0)
df_pivot
# Out:
# user                                                254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user                                                2977    3363    4017    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user                                                4385    6251    6323    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user                                                6543    ...  271705  \
# title                                                       ...
# 1984                                                   0.0  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Without Remorse                                        0.0  ...     0.0
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# user                                                273979  274004  274061  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Year of Wonders                                        9.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user                                                274301  274308  275970  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    8.0     0.0     0.0
#
# user                                                277427  277639  278418
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [673 rows x 812 columns]

# %% [markdown]
# ### Sử dụng thuật toán KNN

# %%
df_matrix = csr_matrix(df_pivot.values)

nn = NearestNeighbors(metric='cosine')

nn.fit(df_matrix)
# Out:
# NearestNeighbors(metric='cosine')

# %% [markdown]
# ### Xây dựng hàm gợi ý

# %%
def get_recommends(book = ""):
    recommended_books = [book,[]]

    distance, book_info = nn.kneighbors([df_pivot.loc[book]], 6, return_distance=True)
    
    recom_book_info = df_pivot.iloc[np.flip(book_info[0])[:-1]].index.to_list()
    recom_distance = list(np.flip(distance[0])[:-1])

    for r in zip(recom_book_info,recom_distance):
        recommended_books[1].append(list(r))
        
    return recommended_books

# %% [markdown]
# ### Kết quả

# %%
get_recommends("Breath, Eyes, Memory")
# Out:
# ['Breath, Eyes, Memory',
#  [['River, Cross My Heart', 0.78799295],
#   ['We Were the Mulvaneys', 0.76867867],
#   ['Jewel', 0.76008],
#   ["Song of Solomon (Oprah's Book Club (Paperback))", 0.7443067],
#   ['Drowning Ruth', 0.68435717]]]
